# %%
indice = [10, 20, 30, 40, 50]
linhas = ['LINHA 10', 'LINHA 20', 'LINHA 30', 'LINHA 40']

for i, l in zip(indice, linhas):
  print(i, l)
# Out:
# 10 LINHA 10
# 20 LINHA 20
# 30 LINHA 30
# 40 LINHA 40
