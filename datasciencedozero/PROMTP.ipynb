# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice/' && git config — global user.email "valentm_araujo@yahoo.com.br" && git config — global user.name “You@Your.com” && git add . && git commit -m "update" && git push -u origin master
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@ef334afc1fc4.(none)')
