# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice/' && git config --global user.email "valentm_araujo@yahoo.com.br" && git config global user.name "Valentim Araújo" && git add . && git commit -m "update" && git push -u origin master
# Out:
# fatal: Unable to create '/content/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
# fatal: Unable to create '/content/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
# error: src refspec master does not match any.
# error: failed to push some refs to 'origin'
