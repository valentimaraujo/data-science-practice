# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice/' && git config --global user.email "valentm_araujo@yahoo.com.br" && git config --global user.name "Valentim Araújo"

# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice/' && git status

# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice/' && git add . && git commit -m "update" && git push -u origin master
# Out:
# [master b9b2aba] update
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite datasciencedozero/PROMTP.ipynb (77%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.26 KiB | 428.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/valentimaraujo/data-science-practice.git
#    f8cff80..b9b2aba  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
