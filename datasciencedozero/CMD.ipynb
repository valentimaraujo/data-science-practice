# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git config — global user.email "valentim_araujo@yahoo.com.br"
# !git config — global user.name "Valentim Araújo"
# !git add . 
# !git commit -m "update" 
# !git remote add origin https://valentima:<password>github@github.com/valentimaraujo/data-science-practice.git https://<username>:<password>github@github.com/<username>/reponame.git
# Out:
# [master f96ef08] update
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite datasciencedozero/CMD.ipynb (88%)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git origin
# Out:
# git: 'origin' is not a git command. See 'git --help'.
