# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git config user.email "valentim_araujo@yahoo.com.br"
# !git config user.name "Valentim Araújo"
# !git config user.username "valentimaraujo"
# !git add . 
# !git commit -m "update" 
# !git push
# Out:
# [master 36ab0c3] update
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite datasciencedozero/CMD.ipynb (78%)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git origin
