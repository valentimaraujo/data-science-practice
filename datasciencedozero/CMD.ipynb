# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git add . 
# !git commit -m "update" 
# !git push -u origin master
# Out:
# [master 8ba4377] update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 571 bytes | 142.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/valentimaraujo/data-science-practice.git
#    5463e09..8ba4377  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git origin
# Out:
# git: 'origin' is not a git command. See 'git --help'.
