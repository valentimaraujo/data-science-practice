# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git config user.email "valentim_araujo@yahoo.com.br"
# !git config --global user.name "ValentimAraújo"
# !git add . 
# !git commit -m "update" 
# !git push
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@1a423ef421e6.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address
