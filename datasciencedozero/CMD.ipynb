# %%
# !cd '/content/drive/My Drive/Estudos/DataScience/data-science-practice'
# !git config user.email "valentim_araujo@yahoo.com.br"
# !git config user.name "Valentim Araújo"
# !git add . 
# !git commit -m "update" 
# !git push
# Out:
# [master e87c301] update
#  15 files changed, 35102 insertions(+)
#  create mode 100644 datasciencedozero/CMD.ipynb
#  create mode 100644 datasciencedozero/PANDAS.ipynb
#  create mode 100644 datasciencedozero/PYTHON TESTS.ipynb
#  create mode 100644 "datasciencedozero/material-apoio/materiais-de-apoio-pandas/.ipynb_checkpoints/Python_Para_Ana\314\201lise_de_Dados_03-checkpoint.ipynb"
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/.ipynb_checkpoints/Python_para_Analise_de_dados_Pandas_01-checkpoint.ipynb
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/.ipynb_checkpoints/Python_para_Analise_de_dados_Pandas_02-checkpoint.ipynb
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/Controle-de-Atividades-2.0.xlsx
#  create mode 100644 "datasciencedozero/material-apoio/materiais-de-apoio-pandas/Python_Para_Ana\314\201lise_de_Dados_03.ipynb"
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/Python_para_Analise_de_dados_Pandas_01.ipynb
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/Python_para_Analise_de_dados_Pandas_02.ipynb
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/inline
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/inplace
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/kc_house_data.csv
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/planilha_pandas.xls
#  create mode 100644 datasciencedozero/material-apoio/materiais-de-apoio-pandas/report.html
# fatal: could not read Username for 'https://github.com': No such device or address
